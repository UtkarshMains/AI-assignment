# %% [markdown]
# <a href="https://colab.research.google.com/github/UtkarshMains/AI-assignment/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.datasets as dsets
import torchvision.transforms as transforms
import torchvision.utils as vutils
import matplotlib.pyplot as plt
import numpy as np
from torch.utils.data import random_split

# Path to the dataset
data_path = './drive/MyDrive/CAT_00/cat'

# Hyperparameters
batch_size = 64
image_size = 64
nz = 100  # Size of the latent vector
ngf = 64  # Size of feature maps in generator
ndf = 64  # Size of feature maps in discriminator
num_epochs = 50  # Increased number of epochs
lr = 0.0002
beta1 = 0.5

# Define the transformation
transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.CenterCrop(image_size),
    transforms.RandomHorizontalFlip(),  # Added data augmentation
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),  # Fixed normalization
])

# Create the dataset
dataset = dsets.ImageFolder(root=data_path, transform=transform)

# Split the dataset into training and validation sets
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# Create dataloaders
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# Define the Generator
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            nn.ConvTranspose2d(nz, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(True),
            nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True),
            nn.ConvTranspose2d(ngf * 4, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),
            nn.ConvTranspose2d(ngf * 2, ngf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf),
            nn.ReLU(True),
            nn.ConvTranspose2d(ngf, 3, 4, 2, 1, bias=False),
            nn.Tanh()
        )

    def forward(self, input):
        return self.main(input)

# Define the Discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            nn.Conv2d(3, ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ndf * 4, ndf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ndf * 8, 1, 4, 1, 0, bias=False),
            nn.Sigmoid()
        )

    def forward(self, input):
        return self.main(input).view(-1)

# Create the generator
netG = Generator().cuda()

# Create the Discriminator
netD = Discriminator().cuda()

# Loss function
criterion = nn.BCELoss()

# Create batch of latent vectors that we will use to visualize the progression of the generator
fixed_noise = torch.randn(64, nz, 1, 1).cuda()

# Establish convention for real and fake labels during training
real_label = 1
fake_label = 0

# Setup Adam optimizers for both G and D
optimizerD = optim.Adam(netD.parameters(), lr=lr, betas=(beta1, 0.999))
optimizerG = optim.Adam(netG.parameters(), lr=lr, betas=(beta1, 0.999))

# Training Loop
img_list = []
G_losses = []
D_losses = []
G_val_losses = []
D_val_losses = []

print("Starting Training Loop...")
iters = 0
for epoch in range(num_epochs):
    for i, data in enumerate(train_dataloader, 0):
        # Update Discriminator
        netD.zero_grad()
        real_cpu = data[0].cuda()
        b_size = real_cpu.size(0)
        label = torch.full((b_size,), real_label, dtype=torch.float, device="cuda")
        output = netD(real_cpu).view(-1)
        errD_real = criterion(output, label)
        errD_real.backward()
        D_x = output.mean().item()

        noise = torch.randn(b_size, nz, 1, 1).cuda()
        fake = netG(noise)
        label.fill_(fake_label)
        output = netD(fake.detach()).view(-1)
        errD_fake = criterion(output, label)
        errD_fake.backward()
        D_G_z1 = output.mean().item()
        errD = errD_real + errD_fake
        optimizerD.step()

        # Update Generator
        netG.zero_grad()
        label.fill_(real_label)
        output = netD(fake).view(-1)
        errG = criterion(output, label)
        errG.backward()
        D_G_z2 = output.mean().item()
        optimizerG.step()

        # Save Losses for plotting later
        G_losses.append(errG.item())
        D_losses.append(errD.item())

        # Check progress of training
        if i % 50 == 0:
            print(f'[{epoch}/{num_epochs}][{i}/{len(train_dataloader)}] '
                  f'Loss_D: {errD.item():.4f} Loss_G: {errG.item():.4f} '
                  f'D(x): {D_x:.4f} D(G(z)): {D_G_z1:.4f} / {D_G_z2:.4f}')

        # Save generated images for later visualization
        if (iters % 500 == 0) or ((epoch == num_epochs-1) and (i == len(train_dataloader)-1)):
            with torch.no_grad():
                fake = netG(fixed_noise).detach().cpu()
            img_list.append(vutils.make_grid(fake, padding=2, normalize=True))

        iters += 1

    # Validation step
    netG.eval()
    netD.eval()
    val_D_losses = 0
    val_G_losses = 0
    with torch.no_grad():
        for i, data in enumerate(val_dataloader, 0):
            real_cpu = data[0].cuda()
            b_size = real_cpu.size(0)
            label = torch.full((b_size,), real_label, dtype=torch.float, device="cuda")
            output = netD(real_cpu).view(-1)
            errD_real = criterion(output, label)
            D_x = output.mean().item()

            noise = torch.randn(b_size, nz, 1, 1).cuda()
            fake = netG(noise)
            label.fill_(fake_label)
            output = netD(fake).view(-1)
            errD_fake = criterion(output, label)
            errD = errD_real + errD_fake
            val_D_losses += errD.item()

            label.fill_(real_label)
            output = netD(fake).view(-1)
            errG = criterion(output, label)
            val_G_losses += errG.item()

    val_D_losses /= len(val_dataloader)
    val_G_losses /= len(val_dataloader)
    D_val_losses.append(val_D_losses)
    G_val_losses.append(val_G_losses)
    netG.train()
    netD.train()

    print(f'Validation Losses - Discriminator: {val_D_losses:.4f}, Generator: {val_G_losses:.4f}')

# Plotting the training and validation loss curves
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training and Validation")
plt.plot(G_losses,label="G - Train")
plt.plot(D_losses,label="D - Train")
plt.plot(G_val_losses,label="G - Val")
plt.plot(D_val_losses,label="D - Val")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

# Visualize the training progression of the GAN
import matplotlib.animation as animation
from IPython.display import HTML

fig = plt.figure(figsize=(8,8))
plt.axis("off")
ims = [[plt.imshow(np.transpose(i,(1,2,0)), animated=True)] for i in img_list]
ani = animation.ArtistAnimation(fig, ims, interval=1000, repeat_delay=1000, blit=True)

HTML(ani.to_jshtml())

# Save the model
torch.save(netG.state_dict(), 'generator.pth')
torch.save(netD.state_dict(), 'discriminator.pth')

# Code for generating cat images
def generate_cats(num_images, model_path='generator.pth', nz=100, save_dir='generated_cats'):
    os.makedirs(save_dir, exist_ok=True)

    # Load the trained generator model
    netG = Generator().cuda()
    netG.load_state_dict(torch.load(model_path))
    netG.eval()

    # Generate images
    for i in range(num_images):
        noise = torch.randn(1, nz, 1, 1).cuda()
        with torch.no_grad():
            fake = netG(noise).detach().cpu()
        img = vutils.make_grid(fake, padding=2, normalize=True).numpy()
        img = np.transpose(img, (1, 2, 0))

        plt.imsave(f"{save_dir}/cat_{i+1}.png", img)

# Generate and save 10 cat images
generate_cats(10)
# Out:
# Starting Training Loop...
# [0/50][0/22] Loss_D: 1.4326 Loss_G: 3.5293 D(x): 0.4990 D(G(z)): 0.5031 / 0.0305
# Validation Losses - Discriminator: 3.1842, Generator: 2.6700
# [1/50][0/22] Loss_D: 0.1408 Loss_G: 13.6832 D(x): 0.8911 D(G(z)): 0.0000 / 0.0000
# Validation Losses - Discriminator: 2.9243, Generator: 5.6928
# [2/50][0/22] Loss_D: 0.0536 Loss_G: 9.1901 D(x): 0.9498 D(G(z)): 0.0001 / 0.0001
# Validation Losses - Discriminator: 2.5985, Generator: 6.5645
# [3/50][0/22] Loss_D: 0.2195 Loss_G: 5.0360 D(x): 0.8375 D(G(z)): 0.0225 / 0.0217
# Validation Losses - Discriminator: 1.0430, Generator: 1.9382
# [4/50][0/22] Loss_D: 0.4045 Loss_G: 4.2061 D(x): 0.8102 D(G(z)): 0.1454 / 0.0189
# Validation Losses - Discriminator: 1.2781, Generator: 0.7170
# [5/50][0/22] Loss_D: 1.1025 Loss_G: 3.1745 D(x): 0.8814 D(G(z)): 0.6065 / 0.0462
# Validation Losses - Discriminator: 1.1624, Generator: 1.1465
# [6/50][0/22] Loss_D: 0.7373 Loss_G: 3.2871 D(x): 0.8936 D(G(z)): 0.4364 / 0.0449
# Validation Losses - Discriminator: 1.1655, Generator: 2.4358
# [7/50][0/22] Loss_D: 0.3571 Loss_G: 4.3841 D(x): 0.7681 D(G(z)): 0.0287 / 0.0178
# Validation Losses - Discriminator: 1.4308, Generator: 1.2941
# [8/50][0/22] Loss_D: 0.8947 Loss_G: 3.0230 D(x): 0.7021 D(G(z)): 0.3478 / 0.0698
# Validation Losses - Discriminator: 1.8536, Generator: 3.0820
# [9/50][0/22] Loss_D: 1.7121 Loss_G: 2.0897 D(x): 0.2833 D(G(z)): 0.0289 / 0.1797
# Validation Losses - Discriminator: 1.9809, Generator: 2.2532
# [10/50][0/22] Loss_D: 1.4302 Loss_G: 1.0584 D(x): 0.3376 D(G(z)): 0.0887 / 0.3993
# Validation Losses - Discriminator: 1.8917, Generator: 0.9985
# [11/50][0/22] Loss_D: 0.5187 Loss_G: 3.9003 D(x): 0.8314 D(G(z)): 0.2659 / 0.0229
# Validation Losses - Discriminator: 2.0030, Generator: 0.6792
# [12/50][0/22] Loss_D: 1.3976 Loss_G: 1.6520 D(x): 0.6298 D(G(z)): 0.5206 / 0.2518
# Validation Losses - Discriminator: 1.0696, Generator: 1.1333
# [13/50][0/22] Loss_D: 0.5280 Loss_G: 4.2641 D(x): 0.8783 D(G(z)): 0.3073 / 0.0154
# Validation Losses - Discriminator: 1.2597, Generator: 1.1980
# [14/50][0/22] Loss_D: 0.4328 Loss_G: 3.2653 D(x): 0.8012 D(G(z)): 0.1644 / 0.0436
# Validation Losses - Discriminator: 1.2625, Generator: 2.3430
# [15/50][0/22] Loss_D: 0.3275 Loss_G: 3.7004 D(x): 0.8430 D(G(z)): 0.1239 / 0.0306
# Validation Losses - Discriminator: 1.2009, Generator: 3.4394
# [16/50][0/22] Loss_D: 0.6660 Loss_G: 3.0975 D(x): 0.6116 D(G(z)): 0.0358 / 0.0653
# Validation Losses - Discriminator: 1.6471, Generator: 1.2882
# [17/50][0/22] Loss_D: 0.7580 Loss_G: 2.5737 D(x): 0.6191 D(G(z)): 0.1741 / 0.1135
# Validation Losses - Discriminator: 1.9764, Generator: 0.6713
# [18/50][0/22] Loss_D: 0.5764 Loss_G: 4.7515 D(x): 0.8813 D(G(z)): 0.3209 / 0.0129
# Validation Losses - Discriminator: 1.5284, Generator: 1.3098
# [19/50][0/22] Loss_D: 0.9409 Loss_G: 2.5466 D(x): 0.5530 D(G(z)): 0.1352 / 0.1150
# Validation Losses - Discriminator: 2.0742, Generator: 3.6040
# [20/50][0/22] Loss_D: 1.5038 Loss_G: 1.3865 D(x): 0.2971 D(G(z)): 0.0295 / 0.3232
# Validation Losses - Discriminator: 1.2936, Generator: 0.8486
# [21/50][0/22] Loss_D: 0.7876 Loss_G: 3.2864 D(x): 0.8908 D(G(z)): 0.4595 / 0.0502
# Validation Losses - Discriminator: 1.6508, Generator: 2.6498
# [22/50][0/22] Loss_D: 0.7686 Loss_G: 2.4041 D(x): 0.5228 D(G(z)): 0.0227 / 0.1124
# Validation Losses - Discriminator: 1.5837, Generator: 1.8455
# [23/50][0/22] Loss_D: 0.4750 Loss_G: 3.7059 D(x): 0.7760 D(G(z)): 0.1642 / 0.0305
# Validation Losses - Discriminator: 0.7496, Generator: 1.7624
# [24/50][0/22] Loss_D: 1.0967 Loss_G: 8.2144 D(x): 0.9656 D(G(z)): 0.6032 / 0.0006
# Validation Losses - Discriminator: 1.5946, Generator: 1.0301
# [25/50][0/22] Loss_D: 0.5078 Loss_G: 2.3977 D(x): 0.7688 D(G(z)): 0.1952 / 0.1023
# Validation Losses - Discriminator: 0.8801, Generator: 1.5045
# [26/50][0/22] Loss_D: 0.4948 Loss_G: 3.8221 D(x): 0.9047 D(G(z)): 0.3017 / 0.0279
# Validation Losses - Discriminator: 1.5219, Generator: 1.2149
# [27/50][0/22] Loss_D: 0.5718 Loss_G: 4.1657 D(x): 0.7816 D(G(z)): 0.2435 / 0.0217
# Validation Losses - Discriminator: 1.4003, Generator: 1.3969
# [28/50][0/22] Loss_D: 0.2830 Loss_G: 3.8492 D(x): 0.8925 D(G(z)): 0.1435 / 0.0301
# Validation Losses - Discriminator: 1.5501, Generator: 1.9227
# [29/50][0/22] Loss_D: 0.3756 Loss_G: 3.1878 D(x): 0.7766 D(G(z)): 0.0942 / 0.0537
# Validation Losses - Discriminator: 2.1718, Generator: 5.3679
# [30/50][0/22] Loss_D: 1.9587 Loss_G: 5.1270 D(x): 0.2089 D(G(z)): 0.0014 / 0.0166
# Validation Losses - Discriminator: 0.9113, Generator: 2.0756
# [31/50][0/22] Loss_D: 0.3125 Loss_G: 4.1475 D(x): 0.8698 D(G(z)): 0.1400 / 0.0202
# Validation Losses - Discriminator: 1.2757, Generator: 2.5784
# [32/50][0/22] Loss_D: 0.3925 Loss_G: 3.7289 D(x): 0.7664 D(G(z)): 0.0701 / 0.0377
# Validation Losses - Discriminator: 2.7713, Generator: 3.6858
# [33/50][0/22] Loss_D: 1.6142 Loss_G: 4.5810 D(x): 0.2699 D(G(z)): 0.0071 / 0.0177
# Validation Losses - Discriminator: 0.8873, Generator: 1.9520
# [34/50][0/22] Loss_D: 0.3146 Loss_G: 3.9315 D(x): 0.8276 D(G(z)): 0.1010 / 0.0292
# Validation Losses - Discriminator: 2.1187, Generator: 0.3285
# [35/50][0/22] Loss_D: 2.7256 Loss_G: 8.6989 D(x): 0.9867 D(G(z)): 0.9168 / 0.0003
# Validation Losses - Discriminator: 1.5025, Generator: 0.9088
# [36/50][0/22] Loss_D: 0.4760 Loss_G: 3.8325 D(x): 0.8697 D(G(z)): 0.2567 / 0.0355
# Validation Losses - Discriminator: 1.4574, Generator: 1.3033
# [37/50][0/22] Loss_D: 0.2156 Loss_G: 4.3896 D(x): 0.9103 D(G(z)): 0.1074 / 0.0163
# Validation Losses - Discriminator: 1.9635, Generator: 0.6314
# [38/50][0/22] Loss_D: 1.0477 Loss_G: 8.4653 D(x): 0.9245 D(G(z)): 0.5922 / 0.0004
# Validation Losses - Discriminator: 1.1014, Generator: 1.6823
# [39/50][0/22] Loss_D: 0.2328 Loss_G: 3.5084 D(x): 0.9203 D(G(z)): 0.1213 / 0.0499
# Validation Losses - Discriminator: 1.5876, Generator: 1.4119
# [40/50][0/22] Loss_D: 1.0594 Loss_G: 7.6421 D(x): 0.9030 D(G(z)): 0.5578 / 0.0008
# Validation Losses - Discriminator: 1.9940, Generator: 4.7238
# [41/50][0/22] Loss_D: 0.9554 Loss_G: 4.3861 D(x): 0.4737 D(G(z)): 0.0028 / 0.0284
# Validation Losses - Discriminator: 1.8522, Generator: 1.4920
# [42/50][0/22] Loss_D: 0.7505 Loss_G: 1.6578 D(x): 0.5908 D(G(z)): 0.1002 / 0.2551
# Validation Losses - Discriminator: 1.2991, Generator: 1.6329
# [43/50][0/22] Loss_D: 1.1961 Loss_G: 7.6323 D(x): 0.9754 D(G(z)): 0.5792 / 0.0013
# Validation Losses - Discriminator: 1.3557, Generator: 1.1767
# [44/50][0/22] Loss_D: 0.5385 Loss_G: 3.8844 D(x): 0.8007 D(G(z)): 0.2234 / 0.0298
# Validation Losses - Discriminator: 0.9789, Generator: 1.7283
# [45/50][0/22] Loss_D: 0.3902 Loss_G: 4.3729 D(x): 0.9741 D(G(z)): 0.2759 / 0.0176
# Validation Losses - Discriminator: 1.2364, Generator: 1.1052
# [46/50][0/22] Loss_D: 0.5718 Loss_G: 4.8669 D(x): 0.9514 D(G(z)): 0.3717 / 0.0108
# Validation Losses - Discriminator: 1.2926, Generator: 1.7753
# [47/50][0/22] Loss_D: 0.2132 Loss_G: 4.6732 D(x): 0.8879 D(G(z)): 0.0733 / 0.0159
# Validation Losses - Discriminator: 1.3476, Generator: 2.8021
# [48/50][0/22] Loss_D: 0.4715 Loss_G: 3.5810 D(x): 0.7112 D(G(z)): 0.0663 / 0.0423
# Validation Losses - Discriminator: 1.6114, Generator: 1.6281
# [49/50][0/22] Loss_D: 0.8150 Loss_G: 3.2318 D(x): 0.5475 D(G(z)): 0.0825 / 0.0718
# Validation Losses - Discriminator: 0.9660, Generator: 1.7719
